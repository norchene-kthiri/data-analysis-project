# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
#to ignore warnings
import warnings
warnings.filterwarnings('ignore')

# %%
#Load the data
df = pd.read_excel('C:/Users/norch/OneDrive/Desktop/AIrteam/Data-analysis-project/DATA/emp_data.xlsx')

# %%
#View the data
df.head()
# Out:
#                                    CODE         NAME_EMP GENDER  \
# 0  0007b03f-c42d-45aa-a582-5f77e01666ec       Amy Nelson      F
# 1  0093eb0b-c058-4ef9-8d41-f9844e8857aa  Richard Pearson      F
# 2  01261e30-d8c5-4dce-b8c5-0352b64f50d2    John Martinez      F
# 3  012eedcf-dd3a-4b66-9e34-040a2e2ae263              NaN      F
# 4  0179e318-2c21-4e88-bd25-17b0dde2b72b    Tamara Wagner      M
#
#                                               ADRESS  MARITAL_STATUS  \
# 0                   PSC 3525, Box 8287\nAPO AE 24254               0
# 1        8634 Cole Causeway\nSharonborough, MP 82894               0
# 2  5929 Ferguson Pine Suite 771\nLake Dorisside, ...               0
# 3            269 Downs Gateway\nMillertown, VA 36972               0
# 4                                                NaN               1
#
#                 GRAD_UNIVERSITY TYPE_DIPLOMA  EXP_YEARS  \
# 0  Gonzales, Berg and Gutierrez     Doctoral        8.0
# ...

# %%
#Basic information

df.info()

#Describe the data

df.describe()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1461 entries, 0 to 1460
# Data columns (total 30 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   CODE                  1461 non-null   object
#  1   NAME_EMP              1458 non-null   object
#  2   GENDER                1461 non-null   object
#  3   ADRESS                1454 non-null   object
#  4   MARITAL_STATUS        1461 non-null   int64
#  5   GRAD_UNIVERSITY       1457 non-null   object
#  6   TYPE_DIPLOMA          1461 non-null   object
#  7   EXP_YEARS             1460 non-null   float64
#  8   EMAIL                 1457 non-null   object
#  9   LANGUAGE              1458 non-null   object
#  10  RANK                  1461 non-null   int64
#  11  GRADE                 1460 non-null   object
#  12  POSITION              1461 non-null   object
#  13  SALARY                744 non-null    float64
#  14  HOURS                 717 non-null    float64
# ...

# %%
#Find the duplicates

df.duplicated().sum()
# Out:
# 0

# %%
df['NAME_EMP'].unique()
# Out:
# array(['Amy Nelson', 'Richard Pearson', 'John Martinez', ...,
#        'Taylor Taylor', 'Katherine Nelson', 'Craig Miller'], dtype=object)

# %%
df['REGISTRATION_NUMBER'].unique()
# Out:
# array(['71ca760c-ee0a-413e-b2e9-e945f30ec24e',
#        '37196908-1c9d-403b-b204-8a938ad86ed4',
#        '0b3e3989-057f-4ad2-91c5-3db4214031fb', ...,
#        'eab13c17-52a9-4d60-9af7-6845ae31a66a',
#        'b486c6ed-2701-4499-ba13-3fc686ce40cc',
#        '692f267e-d21b-45ae-adef-9eed602a6233'], dtype=object)

# %%
df.nunique()
# Out:
# CODE                    1461
# NAME_EMP                1440
# GENDER                     2
# ADRESS                  1454
# MARITAL_STATUS             2
# GRAD_UNIVERSITY         1410
# TYPE_DIPLOMA               3
# EXP_YEARS                 31
# EMAIL                   1453
# LANGUAGE                  64
# RANK                      10
# GRADE                    568
# POSITION                   2
# SALARY                   744
# HOURS                    194
# STARTING_DATE           1335
# REGISTRATION_NUMBER     1460
# TYPE_CONTRACT              3
# DEP_ID                     3
# TECHNOLOGIES               4
# LEAVE_CONSUMED          1455
# LEAVE_BALANCE           1461
# CONTRACT_START          1244
# CONTRACT_END             651
# ID_TRAINING             1440
# ACTIVITY                   3
# TENURE                     2
# ADRESSE_MISSION          517
# LEAVE_TYPE                 4
# SOURCE_of_employment       4
# dtype: int64

# %%
df.isnull().sum()
# Out:
# CODE                      0
# NAME_EMP                  3
# GENDER                    0
# ADRESS                    7
# MARITAL_STATUS            0
# GRAD_UNIVERSITY           4
# TYPE_DIPLOMA              0
# EXP_YEARS                 1
# EMAIL                     4
# LANGUAGE                  3
# RANK                      0
# GRADE                     1
# POSITION                  0
# SALARY                  717
# HOURS                   744
# STARTING_DATE             7
# REGISTRATION_NUMBER       1
# TYPE_CONTRACT             2
# DEP_ID                    4
# TECHNOLOGIES              5
# LEAVE_CONSUMED            6
# LEAVE_BALANCE             0
# CONTRACT_START            0
# CONTRACT_END            720
# ID_TRAINING              20
# ACTIVITY                  2
# TENURE                    0
# ADRESSE_MISSION         944
# LEAVE_TYPE                0
# SOURCE_of_employment      0
# dtype: int64

# %%
df.isnull().sum()
# Out:
# CODE                      0
# NAME_EMP                  3
# GENDER                    0
# ADRESS                    7
# MARITAL_STATUS            0
# GRAD_UNIVERSITY           4
# TYPE_DIPLOMA              0
# EXP_YEARS                 1
# EMAIL                     4
# LANGUAGE                  3
# RANK                      0
# GRADE                     1
# POSITION                  0
# SALARY                  717
# HOURS                   744
# STARTING_DATE             7
# REGISTRATION_NUMBER       1
# TYPE_CONTRACT             2
# DEP_ID                    4
# TECHNOLOGIES              5
# LEAVE_CONSUMED            6
# LEAVE_BALANCE             0
# CONTRACT_START            0
# CONTRACT_END            720
# ID_TRAINING              20
# ACTIVITY                  2
# TENURE                    0
# ADRESSE_MISSION         944
# LEAVE_TYPE                0
# SOURCE_of_employment      0
# dtype: int64

# %%
(df.isnull().sum()/(len(df)))*100
# Out:
# CODE                     0.000000
# NAME_EMP                 0.205339
# GENDER                   0.000000
# ADRESS                   0.479124
# MARITAL_STATUS           0.000000
# GRAD_UNIVERSITY          0.273785
# TYPE_DIPLOMA             0.000000
# EXP_YEARS                0.068446
# EMAIL                    0.273785
# LANGUAGE                 0.205339
# RANK                     0.000000
# GRADE                    0.068446
# POSITION                 0.000000
# SALARY                  49.075975
# HOURS                   50.924025
# STARTING_DATE            0.479124
# REGISTRATION_NUMBER      0.068446
# TYPE_CONTRACT            0.136893
# DEP_ID                   0.273785
# TECHNOLOGIES             0.342231
# LEAVE_CONSUMED           0.410678
# LEAVE_BALANCE            0.000000
# CONTRACT_START           0.000000
# CONTRACT_END            49.281314
# ID_TRAINING              1.368925
# ACTIVITY                 0.136893
# TENURE                   0.000000
# ...

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# Select only numeric columns
numeric_df = df.select_dtypes(include=['number'])

# Calculate the correlation matrix on numeric columns
correlation_matrix = numeric_df.corr()

# Display the correlation matrix as a heatmap
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm', fmt=".2f")

# Show the plot
plt.show()

# %%
from numpy import median
from numpy import abs

# Calculate the median and MAD
median_marital = df['MARITAL_STATUS'].median()
mad_marital = abs(df['MARITAL_STATUS'] - median_marital).median()

# Define a threshold to identify outliers
outlier_limit = 3 * mad_marital

# Identify outliers
outliers_marital = df[abs(df['MARITAL_STATUS'] - median_marital) > outlier_limit]

# %%
# Display the frequency of categories in the column 'NAME_EMP'
print(df['NAME_EMP'].value_counts())
# Out:
# NAME_EMP
# John Ortiz           3
# Daniel Taylor        3
# David Hogan          2
# Joshua Williams      2
# Abigail Taylor       2
#                     ..
# Katherine Johnson    1
# Deborah Mcconnell    1
# James Roberts        1
# Judith Kerr          1
# Craig Miller         1
# Name: count, Length: 1440, dtype: int64

# %%
# Analysis of the distribution by marital status
marital_status_distribution = df['MARITAL_STATUS'].value_counts()

# Display the distribution
plt.figure(figsize=(8, 6))
sns.barplot(x=marital_status_distribution.index, y=marital_status_distribution.values)
plt.title('Distribution by Marital Status')
plt.xlabel('Marital Status')
plt.ylabel('Number of Employees')
plt.xticks(rotation=45, ha='right')
plt.show()

# %%
# To get an idea of the number of occurrences of each gender in our company.
GENDER_counts = df['GENDER'].value_counts()
print(GENDER_counts)
# Out:
# GENDER
# F    731
# M    730
# Name: count, dtype: int64

# %%
# 1. Analysis of distribution by gender
gender_distribution = df['GENDER'].value_counts()

# Create a bar chart for distribution by gender
plt.figure(figsize=(8, 6))
gender_distribution.plot(kind='bar', color=['blue', 'pink'])
plt.title('Employee Distribution by Gender')
plt.xlabel('Gender')
plt.ylabel('Number of Employees')
plt.show()

# %%
# Count the number of employees graduated from each university
university_counts = df['GRAD_UNIVERSITY'].value_counts()

# Display the number of employees graduated from each university
print("Number of employees graduated from each university:")
print(university_counts)
# Out:
# Number of employees graduated from each university:
# GRAD_UNIVERSITY
# White and Sons            5
# Smith and Sons            4
# Johnson Inc               4
# Smith Group               3
# Garcia and Sons           3
#                          ..
# Smith, Kelley and Ford    1
# Myers-Wilson              1
# Miller-Todd               1
# Lucas-Deleon              1
# Dunn, Green and Franco    1
# Name: count, Length: 1410, dtype: int64

# %%
# To get an overview of the diploma levels of our employees
diploma_counts = df['TYPE_DIPLOMA'].value_counts()

print(diploma_counts)
# Out:
# TYPE_DIPLOMA
# Doctoral       503
# Ingeneering    496
# Master         462
# Name: count, dtype: int64

# %%
# 4. Analysis of the distribution by ranks
rank_distribution = df['RANK'].value_counts()

# Create a bar chart for the distribution by rank
plt.figure(figsize=(10, 6))
rank_distribution.plot(kind='bar', color='orange')
plt.title('Distribution of Employees by Rank')
plt.xlabel('Rank')
plt.ylabel('Number of Employees')
plt.show()

# %%
# 7. Time Analysis: Employee Distribution by Year of Hiring
df['STARTING_DATE'] = pd.to_datetime(df['STARTING_DATE'], errors='coerce')
starting_year_distribution = df['STARTING_DATE'].dt.year.value_counts().sort_index()

# Create a bar chart for employee distribution by hiring year
plt.figure(figsize=(12, 6))
starting_year_distribution.plot(kind='bar', color='purple')
plt.title('Employee Distribution by Year of Hiring')
plt.xlabel('Year of Hiring')
plt.ylabel('Number of Employees')
plt.show()

# %%
# To get an overview of TECHNOLOGIES with "CDD" contract type, facilitating workforce management.
cdd_counts = df[df['TYPE_CONTRACT'] == 'CDD'].groupby('RANK').size()

print(cdd_counts)
# Out:
# RANK
# 1     50
# 2     56
# 3     43
# 4     55
# 5     46
# 6     42
# 7     38
# 8     53
# 9     50
# 10    57
# dtype: int64

# %%
# To get an idea of the leave days taken by our employees.
leave_counts = df['LEAVE_CONSUMED'].value_counts()

# Sort the results by number of leave days in ascending order
leave_counts_sorted = leave_counts.sort_index()

# Display the number of employees and the number of leave days for each value
for leave_days, employees in leave_counts_sorted.items():
    print(f"Number of employees with {leave_days} days of leave: {employees}")
# Out:
# Number of employees with 0.0438612160673324 days of leave: 1
# Number of employees with 0.08337253167416958 days of leave: 1
# Number of employees with 0.1232960770237379 days of leave: 1
# Number of employees with 0.1405795685459865 days of leave: 1
# Number of employees with 0.1433381570376058 days of leave: 1
# Number of employees with 0.2011944152152478 days of leave: 1
# Number of employees with 0.2066299418284978 days of leave: 1
# Number of employees with 0.2090196525276689 days of leave: 1
# Number of employees with 0.236228429376375 days of leave: 1
# Number of employees with 0.2661210596053676 days of leave: 1
# Number of employees with 0.2864770062598865 days of leave: 1
# Number of employees with 0.3145500934867607 days of leave: 1
# Number of employees with 0.3217199806394455 days of leave: 1
# Number of employees with 0.3819818910575956 days of leave: 1
# Number of employees with 0.4019047855283819 days of leave: 1
# ...

# %%
# To get an overview of the types of leaves
leave_type_counts = df['LEAVE_TYPE'].value_counts()

print(leave_type_counts)
# Out:
# LEAVE_TYPE
# sans_solde    395
# mission       379
# ordinary      358
# sick          329
# Name: count, dtype: int64

# %%
# 3. Analysis of leave types taken
leave_types_distribution = df['LEAVE_TYPE'].value_counts()

# Create a bar chart or pie chart for the distribution of leave types taken
plt.figure(figsize=(10, 6))
leave_types_distribution.plot(kind='bar', color='lightcoral')
plt.title('Distribution of Leave Types Taken')
plt.xlabel('Type of Leave')
plt.ylabel('Number of Employees')
plt.show()

# %%
# To get an idea of the method by which employees are assigned to the company
source_of_employment_counts = df['SOURCE_of_employment'].value_counts()
print(source_of_employment_counts)
# Out:
# SOURCE_of_employment
# free_application       448
# recruitment_session    421
# recommendation         418
# ex-vacataire           174
# Name: count, dtype: int64

# %%
# 4. Analysis of the distribution by source of employment
source_distribution = df['SOURCE_of_employment'].value_counts()

# Create a bar chart for the distribution by source of employment
plt.figure(figsize=(10, 6))
source_distribution.plot(kind='bar', color='black')
plt.title('Distribution of Employees by Source of Employment')
plt.xlabel('Source of Employment')
plt.ylabel('Number of Employees')

plt.show()

# %%
# Create a histogram for the salary distribution
plt.figure(figsize=(10, 6))
plt.hist(df['SALARY'].dropna(), bins=20, color='skyblue', edgecolor='black')
plt.title('Salary Distribution')
plt.xlabel('Salary')
plt.ylabel('Number of Employees')
plt.show()

# %%
# the number of employees associated with each technological skill.
TECHNOLOGIES_counts = df['TECHNOLOGIES'].value_counts()
print(TECHNOLOGIES_counts)
# Out:
# TECHNOLOGIES
# Software Engineering, Telecom    377
# Software Engineering             371
# Telecom, Software Engineering    364
# Telecom                          344
# Name: count, dtype: int64

# %%
# Display a bar chart of normalized technological skills
plt.figure(figsize=(12, 6))
TECHNOLOGIES_counts.plot(kind='bar', color='skyblue')
plt.title('Frequency of Normalized Technological Skills')
plt.xlabel('Technological Skills')
plt.ylabel('Number of Employees')
plt.xticks(rotation=45, ha='right')  # Rotate labels for better readability
plt.show()

# %%
# 2. Training Analysis (ID_TRAINING)
# Count the frequency of training sessions
training_counts = df['ID_TRAINING'].value_counts()

# Create a bar chart for the most frequent training sessions
plt.figure(figsize=(12, 6))
training_counts.head(10).plot(kind='bar', color='lightgreen')
plt.title('Most Frequent Trainings')
plt.xlabel('Training')
plt.ylabel('Number of Employees')
plt.show()

# %%
# The number of employees associated with each activity.
ACTIVITY_counts = df['ACTIVITY'].value_counts()
print(ACTIVITY_counts)
# Out:
# ACTIVITY
# Mission      516
# Technical    484
# Research     459
# Name: count, dtype: int64

# %%
# 3. Analysis of work-related activities (ACTIVITY)
# Count the frequency of activities
activity_counts = df['ACTIVITY'].value_counts()

# Create a bar chart for the most frequent activities
plt.figure(figsize=(12, 6))
activity_counts.head(10).plot(kind='bar', color='lightcoral')
plt.title('Most Frequent Work-Related Activities')
plt.xlabel('Activity')
plt.ylabel('Number of Employees')
plt.show()

# %%
# The number of employees associated with each position to get an idea about part-time (vacataire) employees.
POSITION_counts = df['POSITION'].value_counts()
print(POSITION_counts)
# Out:
# POSITION
# Permanent    744
# Vacataire    717
# Name: count, dtype: int64

# %%
# Display a bar chart of the number of employees associated with each position
plt.figure(figsize=(12, 6))
POSITION_counts.plot(kind='bar', color='lightblue')
plt.title('Number of Employees by Position')
plt.xlabel('Position')
plt.ylabel('Number of Employees')
plt.xticks(rotation=45, ha='right')  # Rotate labels for better readability
plt.show()

# %%
# Group the data by gender and count the frequency of technologies for each group
technologies_by_gender = df.groupby('GENDER')['TECHNOLOGIES'].value_counts()
print(technologies_by_gender)
# Out:
# GENDER  TECHNOLOGIES
# F       Software Engineering, Telecom    193
#         Telecom                          192
#         Software Engineering             178
#         Telecom, Software Engineering    165
# M       Telecom, Software Engineering    199
#         Software Engineering             193
#         Software Engineering, Telecom    184
#         Telecom                          152
# Name: count, dtype: int64

# %%
# Group the data by gender and count the frequency of technologies for each group
technologies_by_gender = df.groupby('GENDER')['TECHNOLOGIES'].value_counts().unstack()

# Display a stacked bar chart
ax = technologies_by_gender.plot(kind='bar', stacked=True, figsize=(12, 6), colormap='viridis')
plt.title('Technologies by Gender')
plt.xlabel('Gender')
plt.ylabel('Number of Employees')
plt.legend(title='Technologies', bbox_to_anchor=(1, 1))

# Annotate each bar with the corresponding values
for p in ax.patches:
    width, height = p.get_width(), p.get_height()
    x, y = p.get_xy() 
    ax.annotate(f'{int(height)}', (x + width/2, y + height/2), ha='center', va='center')

plt.show()
