# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
df = pd.read_csv("C:/Users/USER/OneDrive - ESPRIT/Bureau/PIBI/[Human Ressources] Employee Insight Hub Unleashing Strategic HR Analytics/departments.csv")
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_13772/442581286.py in <module>
#       3 import seaborn as sns
#       4 import numpy as np
# ----> 5 df = pd.read_csv("C:/Users/USER/OneDrive - ESPRIT/Bureau/PIBI/[Human Ressources] Employee Insight Hub Unleashing Strategic HR Analytics/departments.csv")
#
# ~\anaconda3\lib\site-packages\pandas\util\_decorators.py in wrapper(*args, **kwargs)
#     309                     stacklevel=stacklevel,
#     310                 )
# --> 311             return func(*args, **kwargs)
#     312
#     313         return wrapper
#
# ...

# %%
df
# Out:
#         ID_DEP             DEP  CAPACITY
# 0    DEP_INF00    INFORMATIQUE       601
# 1    DEP_TEL00         TELECOM       300
# 2    DEP_COM01          COMMUN      1262
# 3  DEP_ADMIN00  ADMINISTRATION       200

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4 entries, 0 to 3
# Data columns (total 3 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   ID_DEP    4 non-null      object
#  1   DEP       4 non-null      object
#  2   CAPACITY  4 non-null      int64
# dtypes: int64(1), object(2)
# memory usage: 224.0+ bytes

# %%
df.isnull().sum()
# Out:
# ID_DEP      0
# DEP         0
# CAPACITY    0
# dtype: int64

# %%
df.describe().T
# Out:
#           count    mean         std    min    25%    50%     75%     max
# CAPACITY    4.0  590.75  478.853753  200.0  275.0  450.5  766.25  1262.0

# %%
# Bivariate Analysis - Numerical vs Categorical (CAPACITY vs DEP)

# Aggregate capacity values by department name
capacity_by_dep = df.groupby('DEP')['CAPACITY'].sum().reset_index()

# Create a bar plot
plt.figure(figsize=(10, 6))
sns.barplot(x='DEP', y='CAPACITY', data=capacity_by_dep, palette='pastel')
plt.title('Total Capacity by Department')
plt.xlabel('Department Name')
plt.ylabel('Total Capacity')
plt.xticks(rotation=45)
plt.show()

# %%
# Bivariate Analysis - Numerical vs Categorical (CAPACITY vs DEP)

# Aggregate capacity values by department name
capacity_by_dep = df.groupby('DEP')['CAPACITY'].sum()

# Create a pie chart
plt.figure(figsize=(8, 8))
plt.pie(capacity_by_dep, labels=capacity_by_dep.index, autopct='%1.1f%%', startangle=140, colors=sns.color_palette('pastel'))
plt.title('Distribution of Department Capacities')
plt.axis('equal')  # Equal aspect ratio ensures that pie is drawn as a circle.
plt.show()
