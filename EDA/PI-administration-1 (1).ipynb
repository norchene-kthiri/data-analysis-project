# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

# %%
administration_data = pd.read_excel("C:/Users/norch/OneDrive/Desktop/AIrteam/Data-analysis-project/DATA/administration_data.xlsx")

# %%
administration_data .head(5)
# Out:
#                             ID_Employee       NAME_EMP GENDER  \
# 0  e1856ea4-19a0-4c60-af39-689dced5e0e1   Tony Freeman      F
# 1  80705c76-cbaf-4010-974d-6dde90fe1a69   Donna Larson      F
# 2  90438efd-4d75-4c03-9f23-0821adcaf41b  Lauren Santos      M
# 3  5aeecf88-0749-46f0-b7f5-4801c6a8a143  David Kennedy      M
# 4  5d9df20f-b4c0-473c-8805-4503b34ad728   Casey Turner      M
#
#                                              ADDRESS  MARITAL_STATUS  \
# 0           1087 Blake Spring\nLindsayland, GU 63148               0
# 1    86475 White Ports Suite 192\nMooreton, WV 86516               0
# 2  9702 Wilson Falls Suite 470\nDennisfort, VT 52820               1
# 3                   Unit 6731 Box 3814\nDPO AA 82476               0
# 4  56039 Steven Springs Apt. 717\nMarkmouth, ID 9...               0
#
#           Grade TYPE_DIPLOMA  EXP_YEARS                      EMAIL  \
# 0            RH       Master         17   tony_freeman@example.com
# 1            RH      Licence          8   donna_larson@example.com
# 2     Financier      Licence         11  lauren_santos@example.com
# 3     Financier      Licence          1  david_kennedy@example.com
# 4  Chef Service      Licence         11   casey_turner@example.com
#
#                    LANGUAGE  ...                   REGISTRATION_NUMBER  \
# 0             Arabe, Others  ...  853d05d9-39e0-4ca2-bd84-0c6cc9e62845
# 1                   Anglais  ...  eeef52c4-6ba8-4e66-96fe-0ca90ee3e37e
# 2    Arabe, Anglais, Others  ...  00b4012e-1169-4783-9d3d-f1c810ebf932
# 3    Anglais, Others, Arabe  ...  2519eff5-a640-4729-9614-241f6a6359bb
# 4  Anglais, Arabe, Francais  ...  996a8aa2-3b2a-4fb4-b394-6b19335450ed
#
#   TYPE_CONTRACT       DEP_ID LEAVE_CONSUMED LEAVE_BALANCE CONTRACT_START  \
# 0           CDD  DEP_ADMIN00             13            17     2018-02-28
# 1          CIVP  DEP_ADMIN00              2            26     2019-06-02
# 2           CDI  DEP_ADMIN00              4            28     2014-03-03
# 3           CDI  DEP_ADMIN00             22             4     2011-10-28
# 4           CDD  DEP_ADMIN00             27            10     2017-09-21
#
#   CONTRACT_END  TENURE  LAST_LEAVE_TYPE SOURCE_of_employment
# 0          NaN       1          Mission     Free Application
# 1   2022-12-07       1       Sans_Solde       Recommendation
# 2   2022-03-05       1          Mission       Recommendation
# 3   2023-09-27       1       Sans_Solde     Free Application
# 4          NaN       0       Sans_Solde       Recommendation
#
# [5 rows x 24 columns]

# %% [markdown]
# Il semble y avoir un mélange de données dans votre exemple, mais je vais expliquer l'utilité de chaque colonne en supposant que les données sont structurées comme suit :
#
# 1. *CODE :* Identifiant unique associé à chaque employé (par exemple, numéro d'identification unique).
#
# 2. *NAME_EMP :* Le nom de l'employé (dans cet exemple, Tony Freeman).
#
# 3. *GENDER :* Le genre de l'employé (F pour féminin, M pour masculin, etc.).
#
# 4. *ADDRESS :* L'adresse de résidence de l'employé.
#
# 5. *MARITAL_STATUS :* Le statut matrimonial de l'employé (0 pour célibataire, 1 pour marié, etc.).
#
# 6. *Grade :* Le niveau ou le grade de l'employé au sein de l'organisation (par exemple, RH pour Ressources Humaines).
#
# 7. *TYPE_DIPLOMA :* Le type de diplôme détenu par l'employé (par exemple, Master).
#
# 8. *EXP_YEARS :* Le nombre d'années d'expérience professionnelle de l'employé.
#
# 9. *EMAIL :* L'adresse e-mail de l'employé.
#
# 10. *LANGUAGE :* Les langues que l'employé maîtrise.
#
# 11. *extra_hour :* Le nombre d'heures supplémentaires travaillées par l'employé.
#
# 12. *POSITION :* Le poste occupé par l'employé au sein de l'organisation.
#
# 13. *SALARY :* Le salaire de l'employé.
#
# 14. *STARTING_DATE :* La date à laquelle l'employé a commencé à travailler dans l'entreprise.
#
# 15. *REGISTRATION_NUMBER :* Un numéro d'enregistrement associé à l'employé.
#
# 16. *TYPE_CONTRACT :* Le type de contrat de travail (par exemple, CDD pour Contrat à Durée Déterminée).
#
# 17. *DEP_ID :* L'identifiant du département auquel l'employé est rattaché.
#
# 18. *LEAVE_CONSUMED :* Le nombre de jours de congé déjà pris par l'employé.
#
# 19. *LEAVE_BALANCE :* Le solde de jours de congé restant pour l'employé.
#
# 20. *CONTRACT_START :* La date de début du contrat de travail.
#
# 21. *CONTRACT_END :* La date de fin du contrat de travail.
#
# 22. *TENURE :* La durée totale du service de l'employé dans l'entreprise.   !!!!!!!!!!!!!!!!!!!!!!!!!!!!!
#
# 23. *LAST_LEAVE_TYPE :* Le type de dernier congé pris par l'employé.
#
# 24. *SOURCE_of_employment :* La source par laquelle l'employé a été recruté (par exemple, "Free Application" dans cet exemple).
#
# Chaque colonne dans ces données contient des informations spécifiques sur l'employé, permettant une gestion et une analyse détaillées des ressources humaines au sein de l'organisation.

# %%
# Display the data types of each column
administration_data.dtypes
# Out:
# ID_Employee             object
# NAME_EMP                object
# GENDER                  object
# ADDRESS                 object
# MARITAL_STATUS           int64
# Grade                   object
# TYPE_DIPLOMA            object
# EXP_YEARS                int64
# EMAIL                   object
# LANGUAGE                object
# extra_hour               int64
# POSITION                object
# SALARY                   int64
# STARTING_DATE           object
# REGISTRATION_NUMBER     object
# TYPE_CONTRACT           object
# DEP_ID                  object
# LEAVE_CONSUMED           int64
# LEAVE_BALANCE            int64
# CONTRACT_START          object
# CONTRACT_END            object
# TENURE                   int64
# LAST_LEAVE_TYPE         object
# SOURCE_of_employment    object
# dtype: object

# %%
# Display the dimensions of the DataFrame
# 1279 rows and 24 columns (attributes)
administration_data.shape
# Out:
# (1279, 24)

# %%
# Display the number of null values in each column of the administration_data DataFrame
print(administration_data.isnull().sum())
# Out:
# ID_Employee               0
# NAME_EMP                  0
# GENDER                    0
# ADDRESS                   0
# MARITAL_STATUS            0
# Grade                     0
# TYPE_DIPLOMA              0
# EXP_YEARS                 0
# EMAIL                     0
# LANGUAGE                  0
# extra_hour                0
# POSITION                  0
# SALARY                    0
# STARTING_DATE             0
# REGISTRATION_NUMBER       0
# TYPE_CONTRACT             0
# DEP_ID                    0
# LEAVE_CONSUMED            0
# LEAVE_BALANCE             0
# CONTRACT_START            0
# CONTRACT_END            661
# TENURE                    0
# LAST_LEAVE_TYPE           0
# SOURCE_of_employment      0
# dtype: int64

# %%
# count: Number of non-null observations in each column
# mean: Mean value of each column
# std: Standard deviation, a measure of the dispersion of values around the mean
# min: Minimum value of each column
# 25%: First quartile, the value below which 25% of the data fall
# 50%: Median, the value below which 50% of the data fall
# 75%: Third quartile, the value below which 75% of the data fall
# max: Maximum value of each column

# This output provides summary statistics for each column in the DataFrame, but only for quantitative variables.
print(administration_data.describe())
# Out:
#        MARITAL_STATUS    EXP_YEARS   extra_hour      SALARY  LEAVE_CONSUMED  \
# count     1279.000000  1279.000000  1279.000000  1279.00000     1279.000000
# mean         0.531665    10.069586   101.642690  2944.29398       15.103206
# std          0.499191     5.931192    57.445243  1184.88740        8.936149
# min          0.000000     0.000000     1.000000   902.00000        0.000000
# 25%          0.000000     5.000000    54.000000  1919.00000        7.000000
# 50%          1.000000    10.000000   103.000000  2973.00000       15.000000
# 75%          1.000000    15.000000   153.000000  3990.00000       23.000000
# max          1.000000    20.000000   200.000000  5000.00000       30.000000
#
#        LEAVE_BALANCE       TENURE
# count    1279.000000  1279.000000
# mean       15.000782     0.519937
# std         9.009602     0.499798
# min         0.000000     0.000000
# 25%         7.000000     0.000000
# 50%        15.000000     1.000000
# 75%        22.000000     1.000000
# max        30.000000     1.000000

# %% [markdown]
# # Objective 1 :  Analysis of Employee Demographics:

# %%
# To get an idea about the marital status of our employees
MARITAL_STATUS_counts = administration_data['MARITAL_STATUS'].value_counts()

print(MARITAL_STATUS_counts)
# Out:
# MARITAL_STATUS
# 1    680
# 0    599
# Name: count, dtype: int64

# %%
# 2. Analysis of distribution by marital status
marital_status_distribution = administration_data['MARITAL_STATUS'].value_counts()

# Create a bar chart for distribution by marital status
plt.figure(figsize=(8, 6))
marital_status_distribution.plot(kind='bar', color='skyblue')
plt.title('Employee Distribution by Marital Status')
plt.xlabel('Marital Status')
plt.ylabel('Number of Employees')
plt.show()

# %%
# To get an idea of the count of each gender in our company
GENDER_counts = administration_data['GENDER'].value_counts()
print(GENDER_counts)
# Out:
# GENDER
# M    649
# F    630
# Name: count, dtype: int64

# %%
# 1. Analysis of distribution by gender
gender_distribution = administration_data['GENDER'].value_counts()

# Create a bar chart for gender distribution
plt.figure(figsize=(8, 6))
gender_distribution.plot(kind='bar', color=['blue', 'pink'])
plt.title('Employee Distribution by Gender')
plt.xlabel('Gender')
plt.ylabel('Number of Employees')
plt.show()

# %%
# To get an idea about the positions held by our employees
Grade_counts = administration_data['Grade'].value_counts()
print(Grade_counts)
# Out:
# Grade
# Financier        264
# Director         263
# Communication    255
# Chef Service     252
# RH               245
# Name: count, dtype: int64

# %%
# 3. Analysis of distribution by grade
grade_distribution = administration_data['Grade'].value_counts()

# Create a horizontal bar chart for distribution by grade
plt.figure(figsize=(12, 6))
grade_distribution.plot(kind='barh', color='green')
plt.title('Employee Distribution by Grade')
plt.xlabel('Grade')
plt.ylabel('Number of Employees')
plt.show()

# %%
# To get an idea about the diploma levels of our employees
diploma_counts = administration_data['TYPE_DIPLOMA'].value_counts()

print(diploma_counts)
# Out:
# TYPE_DIPLOMA
# Master      434
# Engineer    424
# Licence     421
# Name: count, dtype: int64

# %%
# 4. Analysis of distribution by diploma type
diploma_distribution = administration_data['TYPE_DIPLOMA'].value_counts()

# Create a bar chart for distribution by diploma type
plt.figure(figsize=(10, 6))
diploma_distribution.plot(kind='bar', color='orange')
plt.title('Employee Distribution by Diploma Type')
plt.xlabel('Diploma Type')
plt.ylabel('Number of Employees')
plt.show()

# %%
TENURE_counts = administration_data['TENURE'].value_counts()
print(TENURE_counts)
# Out:
# TENURE
# 1    665
# 0    614
# Name: count, dtype: int64

# %%
# 6. Cross-analysis: Distribution of grades by gender
cross_gender_grade = pd.crosstab(administration_data['GENDER'], administration_data['Grade'])

# Create a stacked bar chart for grade distribution by gender
ax = cross_gender_grade.plot(kind='bar', stacked=True, colormap='viridis', figsize=(12, 6))
plt.title('Distribution of Grades by Gender')
plt.xlabel('Gender')
plt.ylabel('Number of Employees')

# Add values on the stacked bars
for p in ax.patches:
    width, height = p.get_width(), p.get_height()
    x, y = p.get_xy()
    ax.annotate(f'{int(height)}', (x + width / 2, y + height / 2), ha='center', va='center', fontsize=10)

plt.show()

# %%
# 7. Time analysis: Distribution of employees by year of hire
administration_data['STARTING_DATE'] = pd.to_datetime(administration_data['STARTING_DATE'], errors='coerce')
starting_year_distribution = administration_data['STARTING_DATE'].dt.year.value_counts().sort_index()

# Create a bar chart for the distribution of employees by year of hire
plt.figure(figsize=(12, 6))
ax = starting_year_distribution.plot(kind='bar', color='purple')
plt.title('Employee Distribution by Year of Hire')
plt.xlabel('Year of Hire')
plt.ylabel('Number of Employees')

# Add values on the bars
for p in ax.patches:
    width, height = p.get_width(), p.get_height()
    x, y = p.get_xy()
    ax.annotate(f'{int(height)}', (x + width / 2, y + height), ha='center', va='bottom', fontsize=10)

plt.show()

# %%
# To get an overview of the grades with the contract type "CDD", facilitating workforce management
cdd_counts = administration_data[administration_data['TYPE_CONTRACT'] == 'CDD'].groupby('Grade').size()

print(cdd_counts)
# Out:
# Grade
# Chef Service     82
# Communication    91
# Director         71
# Financier        95
# RH               93
# dtype: int64

# %%
# To get an overview of the number of employees by grade with a NULL value in the "CONTRACT_END" column
null_contract_end_counts = administration_data[administration_data['CONTRACT_END'].isnull()].groupby('Grade').size()
print(null_contract_end_counts)
# Out:
# Grade
# Chef Service     129
# Communication    146
# Director         135
# Financier        128
# RH               123
# dtype: int64

# %%
# Filter data to keep only those with grade "Financier"
rh_data = administration_data[administration_data['Grade'] == 'Financier']

# Sort data by salary in descending order and get top 5
top_rh_salaries = rh_data.sort_values(by='SALARY', ascending=False).head(5)

# Create the bar chart
plt.figure(figsize=(12, 6))
bars = plt.bar(top_rh_salaries['NAME_EMP'], top_rh_salaries['SALARY'])

# Add salary annotations on each bar
for bar, salary in zip(bars, top_rh_salaries['SALARY']):
    plt.text(bar.get_x() + bar.get_width() / 2, bar.get_height(), f'{salary:.2f}', ha='center', va='bottom', fontsize=10)

plt.title('Top 5 Salaries for Employees', fontsize=15)
plt.xlabel('Employee Names', fontsize=12)
plt.xticks(rotation=45, ha='right', fontsize=10)
plt.ylabel('Salary', fontsize=12)
plt.yticks(fontsize=10)
plt.show()

# %% [markdown]
# # Objective 2 :  Contract and Tenure Analysis:

# %%
# To get an overview of the contract types
TYPE_CONTRACT_counts = administration_data['TYPE_CONTRACT'].value_counts()

print(TYPE_CONTRACT_counts)
# Out:
# TYPE_CONTRACT
# CDD     432
# CIVP    427
# CDI     420
# Name: count, dtype: int64

# %%
# 1. Analysis of contract type distribution
contract_type_distribution = administration_data['TYPE_CONTRACT'].value_counts()

# Create a bar chart for contract type distribution
plt.figure(figsize=(8, 6))
contract_type_distribution.plot(kind='bar', color='skyblue')
plt.title('Distribution of Contract Types')
plt.xlabel('Contract Type')
plt.ylabel('Number of Employees')
plt.show()

# %%
# To get an overview of the number of employees whose contracts started each year

# Convert the "CONTRACT_START" column to datetime format
administration_data['CONTRACT_START'] = pd.to_datetime(administration_data['CONTRACT_START'], errors='coerce')

# Filter rows where the contract started between 2010 and 2025
started_between_2010_2025 = administration_data[
    (administration_data['CONTRACT_START'].dt.year >= 2010) & 
    (administration_data['CONTRACT_START'].dt.year <= 2025)
]

# Use groupby to get the count for each year
started_by_year = started_between_2010_2025.groupby(started_between_2010_2025['CONTRACT_START'].dt.year).size()

# Display the count per year
print(started_by_year)
# Out:
# CONTRACT_START
# 2010    115
# 2011    118
# 2012     95
# 2013    100
# 2014    110
# 2015     97
# 2016    115
# 2017    111
# 2018     92
# 2019    101
# 2020    113
# 2021    112
# dtype: int64

# %%
# To get an overview of the number of employees whose contracts ended each year

# Convert the "CONTRACT_END" column to datetime format
administration_data['CONTRACT_END'] = pd.to_datetime(administration_data['CONTRACT_END'], errors='coerce')

# Filter rows where the contract ended between 2021 and 2025
terminated_between_2021_2025 = administration_data[
    (administration_data['CONTRACT_END'].dt.year >= 2021) & 
    (administration_data['CONTRACT_END'].dt.year <= 2025)
]

# Use groupby to get the count for each year
terminated_by_year = terminated_between_2021_2025.groupby(terminated_between_2021_2025['CONTRACT_END'].dt.year).size()

# Display the count per year
print(terminated_by_year)
# Out:
# CONTRACT_END
# 2022    226
# 2023    208
# 2024    184
# dtype: int64

# %%
# 3. Analysis of length of service
administration_data['SERVICE_DURATION'] = administration_data['CONTRACT_END'] - administration_data['CONTRACT_START']
service_duration_stats = administration_data['SERVICE_DURATION'].describe()

# Display descriptive statistics of length of service
print("Descriptive statistics of employees' length of service:\n", service_duration_stats)
# Out:
# Descriptive statistics of employees' length of service:
#  count                             618
# mean     2763 days 13:49:30.873786400
# std      1305 days 01:45:37.867395104
# min                  87 days 00:00:00
# 25%                1717 days 06:00:00
# 50%                2760 days 00:00:00
# 75%                3826 days 00:00:00
# max                5430 days 00:00:00
# Name: SERVICE_DURATION, dtype: object

# %% [markdown]
# # Objective 3 :    Leave Management:

# %% [markdown]
# LEAVE_CONSUMED =  Le nombre de jours de congé déjà pris par l'employé.

# %%
# To get an idea about the number of leave days taken by our employees
leave_counts = administration_data['LEAVE_CONSUMED'].value_counts()

# Sort the results by number of leave days in ascending order
leave_counts_sorted = leave_counts.sort_index()

# Display the number of employees and the corresponding leave days for each value
for leave_days, employees in leave_counts_sorted.items():
    print(f"Number of employees with {leave_days} leave days: {employees}")
# Out:
# Number of employees with 0 leave days: 44
# Number of employees with 1 leave days: 37
# Number of employees with 2 leave days: 37
# Number of employees with 3 leave days: 31
# Number of employees with 4 leave days: 38
# Number of employees with 5 leave days: 48
# Number of employees with 6 leave days: 44
# Number of employees with 7 leave days: 46
# Number of employees with 8 leave days: 50
# Number of employees with 9 leave days: 36
# Number of employees with 10 leave days: 42
# Number of employees with 11 leave days: 33
# Number of employees with 12 leave days: 44
# Number of employees with 13 leave days: 46
# Number of employees with 14 leave days: 43
# Number of employees with 15 leave days: 49
# Number of employees with 16 leave days: 33
# Number of employees with 17 leave days: 42
# Number of employees with 18 leave days: 40
# Number of employees with 19 leave days: 40
# Number of employees with 20 leave days: 48
# Number of employees with 21 leave days: 43
# Number of employees with 22 leave days: 30
# Number of employees with 23 leave days: 37
# Number of employees with 24 leave days: 35
# Number of employees with 25 leave days: 38
# Number of employees with 26 leave days: 47
# Number of employees with 27 leave days: 50
# Number of employees with 28 leave days: 47
# Number of employees with 29 leave days: 39
# Number of employees with 30 leave days: 42

# %% [markdown]
#  Analyse des types de congés pris

# %%
# To get an idea about the types of leave
last_leave_type_counts = administration_data['LAST_LEAVE_TYPE'].value_counts()

print(last_leave_type_counts)
# Out:
# LAST_LEAVE_TYPE
# Sans_Solde    323
# Sick          320
# Mission       319
# Ordinary      317
# Name: count, dtype: int64

# %% [markdown]
# # Objective 4 : Employability Source Analysis:

# %%
# To get an idea about the method by which employees are assigned to the company
source_of_employment_counts = administration_data['SOURCE_of_employment'].value_counts()
print(source_of_employment_counts)
# Out:
# SOURCE_of_employment
# Recommendation         461
# Recruitment Session    435
# Free Application       383
# Name: count, dtype: int64

# %%
# 4. Analysis of the distribution by source of employment
source_distribution = administration_data['SOURCE_of_employment'].value_counts()

# Create a bar chart for the distribution by source of employment
plt.figure(figsize=(10, 6))
source_distribution.plot(kind='bar', color='black')
plt.title('Employee Distribution by Source of Employment')
plt.xlabel('Source of Employment')
plt.ylabel('Number of Employees')
plt.show()

# %% [markdown]
# # objective 5 :   Compensation and Overtime Analysis:

# %%
# To get an overview of the number of overtime hours by grade
extra_hours_by_grade = administration_data.groupby('Grade')['extra_hour'].sum()

# Sort the data in ascending order
extra_hours_by_grade = extra_hours_by_grade.sort_values(ascending=True)

# Create a bar chart
plt.figure(figsize=(12, 6))
extra_hours_by_grade.plot(kind='bar', color='orange')

plt.title('Overtime Hours by Grade (Ascending Order)', fontsize=15)
plt.xlabel('Grade', fontsize=12)
plt.ylabel('Overtime Hours', fontsize=12)
plt.xticks(rotation=45, ha='right', fontsize=10)
plt.show()

# %%
# To get an overview of the number of overtime hours by diploma type
extra_hours_by_diploma = administration_data.groupby('TYPE_DIPLOMA')['extra_hour'].sum()

# Create a bar chart
plt.figure(figsize=(12, 6))
extra_hours_by_diploma.plot(kind='bar', color='orange')
plt.title('Overtime Hours by Diploma Type', fontsize=15)
plt.xlabel('Diploma Type', fontsize=12)
plt.ylabel('Overtime Hours', fontsize=12)
plt.xticks(rotation=45, ha='right', fontsize=10)
plt.show()

# %%
salary_comparison = administration_data.groupby('Grade')['SALARY'].mean().sort_values()

# Create a bar chart to compare salaries between different grades
plt.figure(figsize=(12, 6))
barplot = sns.barplot(x=salary_comparison.index, y=salary_comparison.values, palette='viridis')

# Add each salary value above the corresponding bar
for index, value in enumerate(salary_comparison.values):
    barplot.text(index, value + 50, f'{value:.2f}', ha='center', va='bottom', fontsize=9, color='black')

plt.title('Salary Comparison by Grade')
plt.xlabel('Grade')
plt.ylabel('Average Salary')
plt.show()
